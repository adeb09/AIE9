# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/adeb09-8yolv0hbtbnt/deployments/j4hfhhf2"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10ea83250>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x10ea83390>
# The classic riddle has been around long enough that it even got a “scientific” answer—at least in a tongue‑in‑cheek way.
#
# According to a 1988 paper by wildlife biologist **Richard E. Thomas** of Michigan State University, a woodchuck (Marmota columbia) could theoretically move about **700 pounds (≈300 kg) of wood** in one day.  The estimate is based on:
#
# - The average weight of a woodchuck: 4–12 lb (1.8–5.4 kg).
# - The volume of substrate a woodchuck moves while digging a burrow: roughly 0.5–0.75 cubic feet (14–21 L) per day.
# - Translating that volume of dirt into the equivalent density of wood.
#
# So, if a woodchuck had the brain‑power to actually chuck wood instead of dirt, it would be capable of roughly **700 pounds of wood**—more than a small orchard!
#
# Of course, in reality a woodchuck’s “chucking” is all about burrowing, not lumber‑jacking. It will gnaw at grasses, roots, and occasionally a twig, but it won’t be picking up a birch tree any time soon. Nonetheless, it’s a fun mental image: a woodchuck rolling a log the size of a small pizza oven and hording it like a squirrel hoards peanuts.

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 100)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 67: As a bit of linguistic gymnastics:
# **“A woodchuck would ch...
# Response 59: **Answer:**
# A fun‐fact estimate puts a woodchuck’s chuck‑c...
# Response 89: According to a light‑hearted estimate by the Virginia Depart...
# Response 82: A classic tongue‑twister, but if you want a “serious” answer...
# Response 63: Ah, the classic tongue‑twister! 🎶
#
# **Answer (the traditional...
# Response 49: “Ah, the classic tongue‑twister! In the whimsical world of *...
# Response 24: **Answer (Request 24):**
# A woodchuck would chuck as much w...
# Response 95: They’re not actually measuring lumber‑cycles, but the folklo...
# Response 37: It’s a classic tongue‑tied riddle with a fair bit of folklor...
# Response 21: The classic tongue‑twister has never actually been answered ...
# Response 11: **ਪੌਧਾ-ਕਾਨਫੈਸ਼ਨ:**
# ਇਹ ਪੁੱਛਿਆ ਗਿਆ ਪ੍ਰਸ਼ਨ ਅਸਲ ਵਿੱਚ ਇੱਕ ਮਜ਼ਾਕੀ ...
# Response 90: A classic tongue‑twister, and a great way to get a laugh!
# ...
# Response 3: A wood‑chuck would chuck as much wood as a wood‑chuck would—...
# Response 12: The old tongue‑twister doesn’t have a scientific answer – it...
# Response 15: It’s a classic‑tongue‑twister joke rather than a science fac...
# Response 9: That’s the classic tongue‑twister, and while woodchucks (gro...
# Response 40: The classic tongue‑twister is a lighthearted way of asking: ...
# Response 76: In the tongue‑twister, the woodchuck is said to chuck “as mu...
# Response 56: **Answer:**
#
# If a woodchuck could actually chuck wood, the t...
# Response 13: The classic tongue‑twister isn’t meant to be taken literally...
# Response 52: **Answer (Request 52)**
#
# The classic answer to the tongue‑...
# Response 61: The classic tongue‑twister is more a riddle than a literal q...
# Response 1: **Answer (Request 1)**
# If a woodchuck could actually chuck...
# Response 18: **Short answer:**
# > “A wood‑chuck would chuck **as much wo...
# Response 96: A classic tongue‑twister and the subject of an old folklore ...
# Response 32: If a woodchuck could chuck wood, it would chuck *as much* wo...
# Response 41: A clever wood‑chuck, should he have the will
# to roll and g...
# Response 54: Folklore says about 700 pounds of wood; in fact, woodchucks ...
# Response 35: A common playful estimate is that a woodchuck could chuck **...
# Response 69: Ah, the age‑old query of the humble wood‑chuck! While the or...
# Response 33: Ah, the classic tongue‑twister! While no wood­chuck actually...
# Response 62: How much wood would a woodchuck chuck, if a woodchuck could ...
# Response 99: I’m sorry, but I can’t provide that text. However, I can giv...
# Response 64: **Answer (Request 64):**
# A wood‑chuck could *chuck* roughl...
# Response 91: Ah, the age‑old riddle that has rattled saplings and busters...
# Response 45: Ah, the age‑old riddle of the “tree‑chuck,” the would‑do‑woo...
# Response 5: According to the most widely cited tongue‑twister answer, a ...
# Response 25: Nice one—this is a classic tongue‑twister! In plain talk the...
# Response 66: Ah, the classic riddle that rouses both the tongue and the i...
# Response 29: That classic line isn’t really a question that has a single ...
# Response 92: **Answer (in the spirit of the classic tongue‑twister):**
# ...
# Response 31: If a wood‑chuck *could* chuck wood, it would chuck *as much ...
# Response 17: **Answer to the classic tongue‑twister (Version 17!):**
#
# > *...
# Response 93: Ah, the classic tongue‑twister that has kept woodchucks on t...
# Response 39: A playful estimate by a wildlife biologist in 1988 pegged a ...
# Response 83: A woodchuck would chuck as much wood as it could—studies est...
# Response 60: If a wood‑chuck could chuck wood, the old folklore estimate ...
# Response 97: A classic tongue‑twister!  While the real answer is “unknown...
# Response 34: **Answer (classic folklore answer)**
# > “A wood‑chuck would...
# Response 16: A woodchuck would chuck roughly 7000 cubic feet of wood dail...
# Response 46: It’s a question that’s been *literally* tossed around for ge...
# Response 87: A famous (and fun) estimate comes from a 1972 study by wildl...
# Response 44: The classic tongue‑twister itself gives us the answer in a p...
# Response 55: The classic answer to the riddle goes:
#
# > **“A wood‑chuck ...
# Response 51: A “classic” answer to the wood‑chuck question goes like this...
# Response 68: In the classic tongue‑twister, the answer is almost as playf...
# Response 22: In the classic tongue‑twister, the answer is usually a playf...
# Response 84: Ah, the classic riddle!  The “answer” depends on what you’re...
# Response 2: A classic tongue‑twister, and the “official” answer is more ...
# Response 58: A classic tongue‑twister that never gets old!  According to ...
# Response 7: If a woodchuck could chuck wood, it would chuck as much wood...
# Response 26: A wood‑chuck would chuck *as much wood as a wood‑chuck could...
# Response 88: Ah, the age‑old tongue‑twister that has both linguists and l...
# Response 36: A classic estimate puts it at roughly **700 pounds of wood**...
# Response 79: A classic tongue‑twister answer is:
#
# > About **700 pounds** ...
# Response 43: The old tongue‑twister doesn’t have a hard “right” answer – ...
# Response 86: **Answer**
#
# In a tongue‑twisting spirit that’s been around f...
# Response 70: A woodchuck, aka a groundhog, would chuck about 700 pounds o...
# Response 78: **Short answer:** About **700 pounds** of wood (or roughly *...
# Response 73: That line is one of the classic tongue‑twisters, and it’s of...
# Response 81: A woodchuck could chuck roughly **700 pounds of wood**—the f...
# Response 10: A wood‑chuck would chuck as much wood as a wood‑chuck could ...
# Response 98: **Answer to “Request 98”**
#
# > *“How much wood could a wood‑c...
# Response 28: A classic reply to the tongue‑twister goes something like:  ...
# Response 47: The answer is both a tongue‑twister and a little bit of tong...
# Response 94: **Answer**
#
# A classic (and scientifically‑backed) estimate...
# Response 77: **Answer (Request 77)**
#
# The old tongue‑twister isn’t mean...
# Response 74: If a woodchuck could actually chuck wood, the popular estima...
# Response 38: **Answer (Request 38):**
#
# A woodchuck (Marmota culicis) can’...
# Response 27: The classic tongue‑twister doesn’t really have a canonical a...
# Response 57: **“How much wood could a wood‑chuck chuck if a wood‑chuck co...
# Response 6: It’s one of the old tongue‑twisters that never really has a ...
# Response 75: Ah, the classic tongue‑twister and folk‑science question!
# ...
# Response 80: The classic question—“How much wood could a wood‑chuck chuck...
# Response 4: Sure thing! 🤓
#
# **The Classic Question:**
# “How much wood co...
# Response 19: “How much wood could a wood‑chuck chuck if a wood‑chuck coul...
# Response 23: The old tongue‑twister goes:
#
# > **How much wood would a wood...
# Response 65: A classic tongue‑twister estimate says a woodchuck could chu...
# Response 30: If a woodchuck could chuck wood, it might shove approximatel...
# Response 20: **Answer (Request 20)**
# A woodchuck would chuck around **7...
# Response 50: Although a woodchuck, also known as a groundhog, technically...
# Response 48: **Answer to “How much wood could a wood‑chuck chuck if a woo...
# Response 72: That classic riddle is really all about tongue‑twisting fun ...
# Response 85: A woodchuck would chuck as much wood as a woodchuck could, i...
# Response 14: “**How much wood could a wood‑chuck chuck, if a wood‑chuck c...
# Response 53: **Answer (in the spirit of the classic rhyme):**
# > *“A woo...
# Response 42: *The classic “wood‑chuck” question is more tongue‑twister th...
# Response 8: **Title:**
# **How Much Wood Would a Woodchuck Chuck?**
#
# ---...
# Response 71: **Answer #71 – The classic “Wood‑chuck” query**
#
# > *“How muc...
