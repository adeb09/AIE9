# %%
import aiohttp
import asyncio
import nest_asyncio
import os
from dotenv import load_dotenv
from typing import List, Dict, Any
import json
from github import Github, Auth
from gidgethub.aiohttp import GitHubAPI
import sys

# allow for multiple event loops within Jupyter
nest_asyncio.apply()

# load environment variables
load_dotenv()
# Out:
# True

# %%
# basic GET request
async def fetch_data(url):
    async with aiohttp.ClientSession() as session:
        async with session.get(url) as response:
            # Check status
            if response.status == 200:
                data = await response.json()
                return data
            else:
                print(f"Error: {response.status}")
                return None

# Run the async function
async def main():
    url = "https://api.github.com/user/starred"
    data = await fetch_data(url)
    print(data)

# Execute
asyncio.run(main())
# Out:
# Error: 401
# None

# %%
# fetch Github data
async def fetch_github_data(url, token):
    headers = {
        "Authorization": f"Bearer {token}",
        "Accept": "application/vnd.github+json",
        "X-GitHub-Api-Version": "2022-11-28"
    }

    async with aiohttp.ClientSession(headers=headers) as session:
        async with session.get(url) as response:
            if response.status == 200:
                return await response.json()
            else:
                error_text = await response.text()
                raise Exception(f"Error {response.status}: {error_text}")


async def main():
    token = os.getenv("GITHUB_TOKEN")
    url = "https://api.github.com/user/starred"

    try:
        data = await fetch_github_data(url, token)
        print(f"Retrieved {len(data)} starred repos")
        for repo in data:
            print(f"- {repo['full_name']}: {repo['description']}")
    except Exception as e:
        print(f"Failed: {e}")

asyncio.run(main())
# Out:
# Retrieved 30 starred repos
# - patronus-ai/financebench: None
# - VectifyAI/PageIndex: 📑 PageIndex: Document Index for Vectorless, Reasoning-based RAG
# - erdewit/nest_asyncio: Patch asyncio to allow nested event loops
# - caserec/Datasets-for-Recommender-Systems: This is a repository of a topic-centric public data sources in high quality for Recommender Systems (RS)
# - AnswerDotAI/cachy: Cache your API calls with a single line of code. No mocks, no fixtures. Just faster, cleaner code.
# - PyGithub/PyGithub: Typed interactions with the GitHub API v3
# - cantemizyurek/open-evals: None
# - ThreeDotsLabs/watermill: Building event-driven applications the easy way in Go.
# - ThreeDotsLabs/wild-workouts-go-ddd-example: Go DDD example application. Complete project to show how to apply DDD, Clean Architecture, and CQRS by practical refactoring.
# - pydantic/monty: A minimal, secure Python interpreter written in Rust for use by AI
# - openai/tiktoken: tiktoken is a fast BPE tokeniser for use with OpenAI's models.
# - lyogavin/airllm: AirLLM 70B inference with single 4GB GPU
# - litestar-org/litestar-fullstack: Litestar Fullstack Reference Application with React, Vite, SQLAlchemy, Docker, Task Queues, and more!
# - roborev-dev/roborev: Continuous, non-invasive background code review for agents, to work better and faster. With TUI and CLI support
# - axsaucedo/agent_data_duckdb: None
# - goabiaryan/inferencing_maven: None
# - goabiaryan/RelayServe: Minimal LLM inference server
# - nikhilgarg28/delegate: Delegate your coding work to a team of agents
# - softwaredoug/searcharray: Full text search that feels like a numpy array
# - langchain-ai/openevals: Readymade evaluators for your LLM apps
# - OthmanAdi/planning-with-files: Claude Code skill implementing Manus-style persistent markdown planning — the workflow pattern behind the $2B acquisition.
# - steveyegge/gastown: Gas Town - multi-agent workspace manager
# - BrainBlend-AI/atomic-agents: Building AI agents, atomically
# - alexeygrigorev/sqlitesearch: Persistent alternative to minsearch
# - chr1st1ank/narrow-down: Fast fuzzy text search
# - brandonrobertz/SparseLSH: A Locality Sensitive Hashing (LSH) library with an emphasis on large, highly-dimensional datasets.
# - loretoparisi/lshash: locality sensitive hashing (LSHASH) for Python3
# - anomalyco/opencode: The open source coding agent.
# - microsoft/autogen: A programming framework for agentic AI
# - crewAIInc/crewAI: Framework for orchestrating role-playing, autonomous AI agents. By fostering collaborative intelligence, CrewAI empowers agents to work together seamlessly, tackling complex tasks.

# %%
async def fetch_starred_repos(token: str, number_of_pages: int, per_page: int = 100) -> List[Dict[Any, Any]]:
    """Fetch all starred repositories"""
    headers = {
        "Authorization": f"Bearer {token}",
        "Accept": "application/vnd.github+json",
    }

    all_repos = []
    page = 1

    async with aiohttp.ClientSession(headers=headers) as session:
        while page <= number_of_pages:
            url = f"https://api.github.com/user/starred?per_page={per_page}&page={page}"

            async with session.get(url) as response:
                if response.status != 200:
                    break

                data = await response.json()
                if not data:
                    break

                all_repos.extend(data)
                page += 1

    return all_repos

# %%
async def main():
    token = os.getenv("GITHUB_TOKEN")
    starred_repos = await fetch_starred_repos(token, 10, 100)
    print(f"Retrieved {len(starred_repos)} starred repos")
    return starred_repos

starred_repos = asyncio.run(main())
# Out:
# Retrieved 1000 starred repos

# %%
print(json.dumps(starred_repos[0], indent=4))
# Out:
# {
#     "id": 719213025,
#     "node_id": "R_kgDOKt5R4Q",
#     "name": "financebench",
#     "full_name": "patronus-ai/financebench",
#     "private": false,
#     "owner": {
#         "login": "patronus-ai",
#         "id": 129692268,
#         "node_id": "O_kgDOB7rybA",
#         "avatar_url": "https://avatars.githubusercontent.com/u/129692268?v=4",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/patronus-ai",
#         "html_url": "https://github.com/patronus-ai",
#         "followers_url": "https://api.github.com/users/patronus-ai/followers",
#         "following_url": "https://api.github.com/users/patronus-ai/following{/other_user}",
#         "gists_url": "https://api.github.com/users/patronus-ai/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/patronus-ai/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/patronus-ai/subscriptions",
#         "organizations_url": "https://api.github.com/users/patronus-ai/orgs",
#         "repos_url": "https://api.github.com/users/patronus-ai/repos",
#         "events_url": "https://api.github.com/users/patronus-ai/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/patronus-ai/received_events",
#         "type": "Organization",
#         "user_view_type": "public",
#         "site_admin": false
#     },
#     "html_url": "https://github.com/patronus-ai/financebench",
#     "description": null,
#     "fork": false,
#     "url": "https://api.github.com/repos/patronus-ai/financebench",
#     "forks_url": "https://api.github.com/repos/patronus-ai/financebench/forks",
#     "keys_url": "https://api.github.com/repos/patronus-ai/financebench/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/patronus-ai/financebench/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/patronus-ai/financebench/teams",
#     "hooks_url": "https://api.github.com/repos/patronus-ai/financebench/hooks",
#     "issue_events_url": "https://api.github.com/repos/patronus-ai/financebench/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/patronus-ai/financebench/events",
#     "assignees_url": "https://api.github.com/repos/patronus-ai/financebench/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/patronus-ai/financebench/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/patronus-ai/financebench/tags",
#     "blobs_url": "https://api.github.com/repos/patronus-ai/financebench/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/patronus-ai/financebench/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/patronus-ai/financebench/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/patronus-ai/financebench/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/patronus-ai/financebench/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/patronus-ai/financebench/languages",
#     "stargazers_url": "https://api.github.com/repos/patronus-ai/financebench/stargazers",
#     "contributors_url": "https://api.github.com/repos/patronus-ai/financebench/contributors",
#     "subscribers_url": "https://api.github.com/repos/patronus-ai/financebench/subscribers",
#     "subscription_url": "https://api.github.com/repos/patronus-ai/financebench/subscription",
#     "commits_url": "https://api.github.com/repos/patronus-ai/financebench/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/patronus-ai/financebench/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/patronus-ai/financebench/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/patronus-ai/financebench/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/patronus-ai/financebench/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/patronus-ai/financebench/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/patronus-ai/financebench/merges",
#     "archive_url": "https://api.github.com/repos/patronus-ai/financebench/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/patronus-ai/financebench/downloads",
#     "issues_url": "https://api.github.com/repos/patronus-ai/financebench/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/patronus-ai/financebench/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/patronus-ai/financebench/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/patronus-ai/financebench/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/patronus-ai/financebench/labels{/name}",
#     "releases_url": "https://api.github.com/repos/patronus-ai/financebench/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/patronus-ai/financebench/deployments",
#     "created_at": "2023-11-15T17:39:19Z",
#     "updated_at": "2026-02-26T02:15:45Z",
#     "pushed_at": "2024-12-03T17:29:02Z",
#     "git_url": "git://github.com/patronus-ai/financebench.git",
#     "ssh_url": "git@github.com:patronus-ai/financebench.git",
#     "clone_url": "https://github.com/patronus-ai/financebench.git",
#     "svn_url": "https://github.com/patronus-ai/financebench",
#     "homepage": null,
#     "size": 564876,
#     "stargazers_count": 258,
#     "watchers_count": 258,
#     "language": "Jupyter Notebook",
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": false,
#     "has_discussions": false,
#     "forks_count": 47,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 7,
#     "license": null,
#     "allow_forking": true,
#     "is_template": false,
#     "web_commit_signoff_required": false,
#     "has_pull_requests": true,
#     "pull_request_creation_policy": "all",
#     "topics": [],
#     "visibility": "public",
#     "forks": 47,
#     "open_issues": 7,
#     "watchers": 258,
#     "default_branch": "main",
#     "permissions": {
#         "admin": false,
#         "maintain": false,
#         "push": false,
#         "triage": false,
#         "pull": true
#     }
# }

# %%
token = os.getenv("GITHUB_TOKEN")
print(token)
# Out:
# None

# %%
async def get_url(url: str):
    async with session.get(url) as response:
        if response.status == 200:
            return await response.json()
        else:
            error_text = await response.text()
            raise Exception(f"Error {response.status}: {error_text}")

# %%
async def main():
    token = os.getenv("GITHUB_TOKEN")
    url = "https://api.github.com/user/starred"

    try:
        data = await fetch_github(url, token)
        print(f"Retrieved {len(data)} starred repos")
        for repo in data:
            print(f"- {repo['full_name']}: {repo['description']}")
    except Exception as e:
        print(f"Failed: {e}")

# %%
token

# %%
# authenticate PyGithub using token
token = os.getenv("GITHUB_TOKEN")
auth = Auth.Token(token)
g = Github(auth=auth)

# %%
dir(g)
# Out:
# ['FIX_REPO_GET_GIT_REF',
#  '_Github__requester',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'close',
#  'create_from_raw_data',
#  'default_retry',
#  'dump',
#  'get_app',
#  'get_emojis',
#  'get_enterprise',
#  'get_events',
#  'get_gist',
#  'get_gists',
#  'get_gitignore_template',
#  'get_gitignore_templates',
#  'get_global_advisories',
#  'get_global_advisory',
#  'get_hook',
#  'get_hook_deliveries',
#  'get_hook_delivery',
#  'get_hooks',
#  'get_license',
#  'get_licenses',
#  'get_oauth_application',
#  'get_organization',
#  'get_organizations',
#  'get_project',
#  'get_project_column',
#  'get_rate_limit',
#  'get_repo',
#  'get_repos',
#  'get_repository_discussion',
#  'get_user',
#  'get_user_by_id',
#  'get_users',
#  'load',
#  'oauth_scopes',
#  'per_page',
#  'rate_limiting',
#  'rate_limiting_resettime',
#  'render_markdown',
#  'requester',
#  'search_code',
#  'search_commits',
#  'search_issues',
#  'search_repositories',
#  'search_topics',
#  'search_users',
#  'withLazy']

# %%
user = g.get_user()

# %%
starred = user.get_starred()

# %%
for star in starred:
    print(star)
    break
# Out:
# Repository(full_name="patronus-ai/financebench")

# %% [markdown]
# #### GidgetHub Examples

# %%
async def main():
    # Get OAuth token from environment
    oauth_token = os.getenv("GITHUB_TOKEN")

    async with aiohttp.ClientSession() as session:
        # Create GitHub API instance
        gh = GitHubAPI(session, "your-username",
                      oauth_token=oauth_token)

        # Your API calls here
        print(f"Rate limit remaining: {gh.rate_limit}")
        return gh

gh = asyncio.run(main())
# Out:
# Rate limit remaining: None

# %%
async def get_my_starred_repos():
    """Fetch all starred repositories for authenticated user"""
    oauth_token = os.getenv("GITHUB_TOKEN")

    async with aiohttp.ClientSession() as session:
        gh = GitHubAPI(session, "my-script", oauth_token=oauth_token)

        # Use getiter() for automatic pagination
        starred_repos = []

        async for repo in gh.getiter("/user/starred"):
            starred_repos.append(repo)
            # print(f"⭐ {repo['full_name']}")
            # print(f"   Description: {repo['description']}")
            # print(f"   Stars: {repo['stargazers_count']}")
            # print(f"   Language: {repo['language']}")
            # print()

        print(f"\nTotal starred repositories: {len(starred_repos)}")
        return starred_repos

starred_repos = asyncio.run(get_my_starred_repos())
# Out:
# /Users/abirvabdeb/.pyenv/versions/3.13.11/lib/python3.13/json/decoder.py:361: RuntimeWarning: coroutine 'fetch_starred_repos' was never awaited
#   obj, end = self.scan_once(s, idx)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Total starred repositories: 2033

# %%
def deep_sizeof(obj, seen=None):
    if seen is None:
        seen = set()
    obj_id = id(obj)
    if obj_id in seen:
        return 0
    seen.add(obj_id)
    size = sys.getsizeof(obj)
    if hasattr(obj, '__dict__'):
        size += deep_sizeof(obj.__dict__, seen)
    if hasattr(obj, '__iter__') and not isinstance(obj, (str, bytes, bytearray)):
        size += sum(deep_sizeof(item, seen) for item in obj)
    return size

# %%
deep_sizeof(starred_repos)
# Out:
# 3528048

# %%
sys.getsizeof(starred_repos)
# Out:
# 18232

# %%
starred_repos[0]
# Out:
# {'id': 79673050,
#  'node_id': 'MDEwOlJlcG9zaXRvcnk3OTY3MzA1MA==',
#  'name': 'gidgethub',
#  'full_name': 'gidgethub/gidgethub',
#  'private': False,
#  'owner': {'login': 'gidgethub',
#   'id': 138931485,
#   'node_id': 'O_kgDOCEftHQ',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/138931485?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/gidgethub',
#   'html_url': 'https://github.com/gidgethub',
#   'followers_url': 'https://api.github.com/users/gidgethub/followers',
#   'following_url': 'https://api.github.com/users/gidgethub/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/gidgethub/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/gidgethub/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/gidgethub/subscriptions',
#   'organizations_url': 'https://api.github.com/users/gidgethub/orgs',
#   'repos_url': 'https://api.github.com/users/gidgethub/repos',
#   'events_url': 'https://api.github.com/users/gidgethub/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/gidgethub/received_events',
#   'type': 'Organization',
#   'user_view_type': 'public',
#   'site_admin': False},
#  'html_url': 'https://github.com/gidgethub/gidgethub',
#  'description': 'An async GitHub API library for Python',
#  'fork': False,
#  'url': 'https://api.github.com/repos/gidgethub/gidgethub',
#  'forks_url': 'https://api.github.com/repos/gidgethub/gidgethub/forks',
#  'keys_url': 'https://api.github.com/repos/gidgethub/gidgethub/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/gidgethub/gidgethub/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/gidgethub/gidgethub/teams',
#  'hooks_url': 'https://api.github.com/repos/gidgethub/gidgethub/hooks',
#  'issue_events_url': 'https://api.github.com/repos/gidgethub/gidgethub/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/gidgethub/gidgethub/events',
#  'assignees_url': 'https://api.github.com/repos/gidgethub/gidgethub/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/gidgethub/gidgethub/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/gidgethub/gidgethub/tags',
#  'blobs_url': 'https://api.github.com/repos/gidgethub/gidgethub/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/gidgethub/gidgethub/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/gidgethub/gidgethub/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/gidgethub/gidgethub/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/gidgethub/gidgethub/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/gidgethub/gidgethub/languages',
#  'stargazers_url': 'https://api.github.com/repos/gidgethub/gidgethub/stargazers',
#  'contributors_url': 'https://api.github.com/repos/gidgethub/gidgethub/contributors',
#  'subscribers_url': 'https://api.github.com/repos/gidgethub/gidgethub/subscribers',
#  'subscription_url': 'https://api.github.com/repos/gidgethub/gidgethub/subscription',
#  'commits_url': 'https://api.github.com/repos/gidgethub/gidgethub/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/gidgethub/gidgethub/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/gidgethub/gidgethub/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/gidgethub/gidgethub/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/gidgethub/gidgethub/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/gidgethub/gidgethub/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/gidgethub/gidgethub/merges',
#  'archive_url': 'https://api.github.com/repos/gidgethub/gidgethub/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/gidgethub/gidgethub/downloads',
#  'issues_url': 'https://api.github.com/repos/gidgethub/gidgethub/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/gidgethub/gidgethub/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/gidgethub/gidgethub/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/gidgethub/gidgethub/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/gidgethub/gidgethub/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/gidgethub/gidgethub/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/gidgethub/gidgethub/deployments',
#  'created_at': '2017-01-21T21:08:59Z',
#  'updated_at': '2026-02-26T05:42:07Z',
#  'pushed_at': '2025-08-11T23:09:56Z',
#  'git_url': 'git://github.com/gidgethub/gidgethub.git',
#  'ssh_url': 'git@github.com:gidgethub/gidgethub.git',
#  'clone_url': 'https://github.com/gidgethub/gidgethub.git',
#  'svn_url': 'https://github.com/gidgethub/gidgethub',
#  'homepage': 'https://gidgethub.readthedocs.io',
#  'size': 484,
#  'stargazers_count': 404,
#  'watchers_count': 404,
#  'language': 'Python',
#  'has_issues': True,
#  'has_projects': True,
#  'has_downloads': True,
#  'has_wiki': False,
#  'has_pages': False,
#  'has_discussions': True,
#  'forks_count': 60,
#  'mirror_url': None,
#  'archived': False,
#  'disabled': False,
#  'open_issues_count': 28,
#  'license': {'key': 'apache-2.0',
#   'name': 'Apache License 2.0',
#   'spdx_id': 'Apache-2.0',
#   'url': 'https://api.github.com/licenses/apache-2.0',
#   'node_id': 'MDc6TGljZW5zZTI='},
#  'allow_forking': True,
#  'is_template': False,
#  'web_commit_signoff_required': False,
#  'has_pull_requests': True,
#  'pull_request_creation_policy': 'all',
#  'topics': ['aiohttp',
#   'async',
#   'github',
#   'httpx',
#   'python',
#   'sans-io',
#   'tornado',
#   'treq',
#   'twisted'],
#  'visibility': 'public',
#  'forks': 60,
#  'open_issues': 28,
#  'watchers': 404,
#  'default_branch': 'main',
#  'permissions': {'admin': False,
#   'maintain': False,
#   'push': False,
#   'triage': False,
#   'pull': True}}

# %%
for repo in starred_repos:
    description = repo.get('description')
    name = repo.get('full_name')
    if description and 'nvidia' in description:
        print(repo)
        continue
    if name and 'nvidia' in name:
        print(repo)

# %%
len(starred_repos)
# Out:
# 2033
